# %%
using ArraySignalProcessing
using LinearAlgebra

fc = 150e6

# Spacing:  1m is λ/2 for 150MHz 
# Oriented along yaxis to match Matlab behavior
ia = IsotropicArray([0 0 0 0;
                    -1.5 -0.5 0.5 1.5])
Δ = 1

# test signal generation
Rss = I(2)
Θ = deg2rad.([10, 65])
d = length(Θ)
N = 300
SNR = 15
X = unconditional_signals(ia, Rss, N, SNR, Θ, fc)

θgrid = Vector(-90:90)
A = ia(deg2rad.(θgrid), fc)
spectrum = bpdn(X, A, 10)
threshold = 15
Θest = θgrid[spectrum .> threshold]
println(Θest)
println(spectrum[spectrum .> threshold])
# Out:
# ------------------------------------------------------------------
# 	       SCS v3.2.11 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 108782, constraints m: 111183
# cones: 	  l: linear vars: 1
# 	  q: soc vars: 111182, qsize: 182
# settings: eps_abs: 1.0e-04, eps_rel: 1.0e-04, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# 	  compiled with openmp parallelization enabled
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 975183, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 2.00e+01  1.00e+00  3.62e+03 -1.81e+03  1.00e-01  1.59e-01
#    250| 1.80e-02  5.49e-04  6.71e-02  1.94e+01  1.00e-01  1.07e+00
#    500| 3.56e-03  1.75e-04  1.34e-02  1.94e+01  1.00e-01  1.98e+00
#    750| 6.49e-04  1.23e-04  3.58e-03  1.94e+01  1.00e-01  2.86e+00
#    875| 3.15e-04  1.20e-04  1.95e-03  1.94e+01  1.00e-01  3.29e+00
# ------------------------------------------------------------------
# status:  solved
# timings: total: 3.29e+00s = setup: 1.49e-01s + solve: 3.15e+00s
# 	 lin-sys: 2.29e+00s, cones: 2.26e-01s, accel: 1.36e-01s
# ------------------------------------------------------------------
# objective = 19.437831
# ------------------------------------------------------------------
# [10]
# [33.55657675025809]
# ┌ Info: [Convex.jl] Compilation finished: 1.56 seconds, 1.740 GiB of memory allocated
# └ @ Convex C:\Users\matt\.julia\packages\Convex\Gb22x\src\solution.jl:107

# %%
using Plots
import Measures
p1 = plot(θgrid, 10*log10.(abs.(spectrum)),marker=:dot, label="spectrum")
plot!(title="BPDN Spectrum", margin=5*Measures.mm)
plot!(θgrid,  10*log10.(threshold)*ones(length(θgrid),1), label="threshold")
xlabel!("Azimuth in degree")
ylabel!("Power in dB")
